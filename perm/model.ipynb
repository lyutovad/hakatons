# %%
import pandas as pd

from sklearn.preprocessing import LabelEncoder

import xgboost as xgb

import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split

import shap

# %%
df = pd.read_csv('dataset2.csv')
df
# Out:
#      Unnamed: 0                                               Name  \
# 0             0  Благотворительный фонд социальной поддержки на...
# 1             1  Благотворительный фонд помощи тяжело больным д...
# 2             2  Автономная некоммерческая медицинская организа...
# 3             3         Детский Благотворительный Фонд "С Любовью"
# 4             4  Благотворительный фонд помощи тяжелобольным де...
# ..          ...                                                ...
# 507         507  Благотворительный фонд помощи "Звезда Милосердия"
# 508         508                              Центр защиты прав СМИ
# 509         509                     Фонд защиты городских животных
# 510         510                      Благотворительный фонд «РДКМ»
# 511         511                 Всемирный фонд дикой природы (WWF)
#
#                 City  INN  reliable  dobro_mail  need_help  https  legal_fee
# 0    Благовещенск РБ    1         1           1          1      0          1
# 1                Уфа    1         1           1          1      0          1
# 2                Уфа    1         1           1          1      0          1
# 3                Уфа    1         1           1          1      1          1
# 4                Уфа    1         1           1          1      0          1
# ..               ...  ...       ...         ...        ...    ...        ...
# 507           Москва    0         1           1          1      0          1
# 508          Воронеж    0         1           1          1      0          1
# 509           Москва    0         1           1          1      0          1
# 510           Москва    0         1           1          1      0          1
# 511           Москва    0         1           1          1      0          1
#
# [512 rows x 9 columns]

# %%
target = df['reliable']
data = df.drop(['Unnamed: 0', 'reliable', 'Name'], axis=1)

data["City"] = data["City"].astype(str)

# %%
encoder = LabelEncoder()
categorical = data.dtypes[data.dtypes=="object"].index.tolist()

data[categorical] = data[categorical].apply(encoder.fit_transform)

# %%
dtrain = xgb.DMatrix(data, target)

# %%
params = {
    "eta": 0.01,
    "objective": "binary:logistic",
    "subsample": 0.5,
    "eval_metric": "auc",
    
}
model = xgb.train(
    params,
    dtrain,
    num_boost_round=5000,
    verbose_eval=500
)

# %% [markdown]
# ### Классические меры важности XGBoost

# %%
fig, ax = plt.subplots(1, 1, figsize=(10, 8))
xgb.plot_importance(model, ax=ax)
plt.title("xgboost.plot_importance(model, importance_type='weight')")
plt.show()

fig, ax = plt.subplots(2, 1, figsize=(10, 18))
xgb.plot_importance(model, ax=ax[0], importance_type="cover")
ax[0].set_title("xgboost.plot_importance(model, importance_type='cover')")

xgb.plot_importance(model, ax=ax[1], importance_type="gain")
ax[1].set_title("xgboost.plot_importance(model, importance_type='gain')")
plt.show()

# %% [markdown]
# Weight - сколько раз признак использовался для разбиения вершины дерева, по всем деревьям.
#
# Cover - количество раз, когда признак используется для разбиения вершины данных, взвешенная на долю наблюдений обучающей выборки, которая проходит через это разбиение. Считается по всем деревьям.
#
# Gain - среднее снижение значения функции потерь при обучении, полученное при данного признака.

# %% [markdown]
# ### SHAP Summary Plot

# %%
explainer = shap.TreeExplainer(model)
shap_values = explainer.shap_values(data, target)

# %%
shap.force_plot(
    explainer.expected_value, shap_values[0,:], data.iloc[0,:], link="logit"
)
# Out:
# <div id='iOUCYUVV3DSS2ZV6UNLKH'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": 4.347569942474365, "outValue": 4.995620250701904, "link": "logit", "featureNames": ["City", "INN", "dobro_mail", "need_help", "https", "legal_fee"], "features": {"0": {"effect": -0.2224212884902954, "value": 5.0}, "1": {"effect": -0.34007132053375244, "value": 1.0}, "5": {"effect": 1.2105430364608765, "value": 1.0}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('iOUCYUVV3DSS2ZV6UNLKH')
#   );
# </script>

# %%
shap.summary_plot(shap_values, data, plot_type="bar", max_display=data.shape[1])

# %%
shap.summary_plot(shap_values, data)

# %%
dependence_features = data.columns

for name in dependence_features:
    shap.dependence_plot(name, shap_values, data, display_features=data)
# Out:
# Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
# invalid value encountered in true_divide
# invalid value encountered in true_divide

# %%
test = pd.read_csv('test2.csv')
test
# Out:
#    Unnamed: 0                        Name       City  INN  dobro_mail  \
# 0           0  Служба помощи «Милосердие»     Москва    1           1
# 1           1          Вы в нас нужаетесь  Челябинск    1           0
#
#    need_help  https  legal_fee
# 0          0      1          1
# 1          0      0          0

# %%
test[categorical] = test[categorical].apply(encoder.transform)

# %%
test.drop(['Unnamed: 0', 'Name'], axis=1, inplace=True)

# %%
dtest = xgb.DMatrix(test)
model.predict(dtest)
# Out:
# array([0.9950891, 0.1875508], dtype=float32)
